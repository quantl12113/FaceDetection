# %% [markdown]
# <a href="https://colab.research.google.com/github/quantl12113/FaceDetection/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/rajeevyasarla/UMSN-Face-Deblurring.git
# Out:
# Cloning into 'UMSN-Face-Deblurring'...
# remote: Enumerating objects: 32, done.
# remote: Counting objects: 100% (32/32), done.
# remote: Compressing objects: 100% (32/32), done.
# remote: Total 152 (delta 16), reused 0 (delta 0), pack-reused 120
# Receiving objects: 100% (152/152), 335.38 MiB | 37.97 MiB/s, done.
# Resolving deltas: 100% (62/62), done.
# Checking out files: 100% (63/63), done.

# %%
# !pip install torch==0.4.1
# Out:
# ...
#      |████████████████████████████████| 519.5MB 30kB/s
# ERROR: torchvision 0.5.0 has requirement torch==1.4.0, but you'll have torch 0.4.1 which is incompatible.
# ERROR: fastai 1.0.60 has requirement torch>=1.0.0, but you'll have torch 0.4.1 which is incompatible.
# ...
#   Found existing installation: torch 1.4.0
#     Uninstalling torch-1.4.0:
#       Successfully uninstalled torch-1.4.0
# ...

# %%
# !pip install torchvision==0.2.1

# %%
# %cd ..
# Out:
# /content/test

# %%
# !python test_face_deblur.py --dataroot ./facades/github/ --valDataroot ./testData --netG ./pretrained_models/Deblur_epoch_Best.pth
# Out:
# Namespace(annealEvery=400, annealStart=0, batchSize=1, beta1=0.5, dataroot='./facades/github/', dataset='pix2pix', display=5, evalIter=500, exp='sample', imageSize=128, inputChannelSize=3, lambdaGAN=0.01, lambdaIMG=1, lrD=0.0002, lrG=0.0002, mode='B2A', ndf=64, netD='', netG='./pretrained_models/Deblur_epoch_Best.pth', ngf=64, niter=400, originalSize=128, outputChannelSize=3, poolSize=50, valBatchSize=1, valDataroot='./testData', wd=0.0, workers=1)
# Random Seed:  6347
# Deblur_segdl(
#   (deblur_class1): Deblur_first(
#     (dense_block1): BottleneckBlockrs(
#       (bn1): InstanceNorm2d(4, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#       (relu): ReLU(inplace)
#       (conv_o): Conv2d(4, 28, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (conv1): Conv2d(4, 84, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn2): InstanceNorm2d(84, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
# ...

# %%
# !pip install Pillow==6.2.2
# Out:
# ...
#      |████████████████████████████████| 2.1MB 13.2MB/s
# ERROR: fastai 1.0.60 has requirement torch>=1.0.0, but you'll have torch 0.4.1 which is incompatible.
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# ...
#   Found existing installation: Pillow 7.0.0
#     Uninstalling Pillow-7.0.0:
#       Successfully uninstalled Pillow-7.0.0
# ...
